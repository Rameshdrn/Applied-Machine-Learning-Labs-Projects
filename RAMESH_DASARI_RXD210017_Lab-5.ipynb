# %% [markdown]
#    # Lab 5 - Template

# %% [markdown]
# The template is given as starting point to help you get up to speed with loading file and understanding data.
# Use the template and answer each question in the appropriate cell.
#
# Submit:
# - eLearning
# - Github: create new folder Lab-5. Commit your work under the folder
#
# Naming: First-name_Last_name_ID_Lab_5.ipynb

# %% [markdown]
# ## Dataset description
#
# The dataset for Lab-5 is sample of the SBA dataset posted on Kaggle.
#
# The dataset is from the U.S. Small Business Administration (SBA)
# The U.S. SBA was founded in 1953 on the principle of promoting and assisting small enterprises in the U.S. credit market
# (SBA Overview and History, US Small Business Administration (2015)). Small businesses have been a primary source of job creation in the United States; therefore, fostering small business formation and growth has social benefits by creating job opportunities and reducing unemployment.
# There have been many success stories of start-ups receiving SBA loan guarantees such as FedEx and Apple Computer.
# However, there have also been stories of small businesses and/or start-ups that have defaulted on their SBA-guaranteed loans.
#
# More info on the original dataset: https://www.kaggle.com/mirbektoktogaraev/should-this-loan-be-approved-or-denied

# %% [markdown]
# ## Preparation
#
# Load same data into H2O-3 dataframe.
# Describe imported dataframe.

# %%
# !pip install h2o
# Out:
# Requirement already satisfied: h2o in /Applications/anaconda3/lib/python3.9/site-packages (3.36.0.3)
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.9/site-packages (from h2o) (2.26.0)
# Requirement already satisfied: future in /Applications/anaconda3/lib/python3.9/site-packages (from h2o) (0.18.2)
# Requirement already satisfied: tabulate in /Applications/anaconda3/lib/python3.9/site-packages (from h2o) (0.8.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/anaconda3/lib/python3.9/site-packages (from requests->h2o) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.9/site-packages (from requests->h2o) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from requests->h2o) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.9/site-packages (from requests->h2o) (2021.10.8)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Applications/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import h2o
try:
    h2o.cluster().shutdown()
except:
    pass 
#Limit to 3 threads and 4GB memory
h2o.init(nthreads=3, max_mem_size=8)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_321"; Java(TM) SE Runtime Environment (build 1.8.0_321-b07); Java HotSpot(TM) 64-Bit Server VM (build 25.321-b07, mixed mode)
#   Starting server from /Applications/anaconda3/lib/python3.9/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/8l/yc73vvl93h35z67s8hh5_jjw0000gn/T/tmp373sc_rz
#   JVM stdout: /var/folders/8l/yc73vvl93h35z67s8hh5_jjw0000gn/T/tmp373sc_rz/h2o_dasariramesh_started_from_python.out
#   JVM stderr: /var/folders/8l/yc73vvl93h35z67s8hh5_jjw0000gn/T/tmp373sc_rz/h2o_dasariramesh_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       America/Chicago
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.0.3
# H2O_cluster_version_age:    19 days
# H2O_cluster_name:           H2O_from_python_dasariramesh_nq5c8d
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.104 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  3
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.7 final
# --------------------------  -----------------------------------

# %%
df_h = h2o.import_file('SBA_loans_lab_5.zip')
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
df_h.describe()
# Out:
# Rows:449582
# Cols:20
# <table>
# <thead>
# <tr><th>       </th><th>City       </th><th>State  </th><th>Zip               </th><th>Bank                          </th><th>BankState  </th><th>NAICS             </th><th>Term              </th><th>NoEmp            </th><th>NewExist          </th><th>CreateJob         </th><th>RetainedJob       </th><th>FranchiseCode     </th><th>UrbanRural        </th><th>RevLineCr  </th><th>LowDoc  </th><th>DisbursementGross  </th><th>BalanceGross      </th><th>GrAppv            </th><th>SBA_Appv          </th><th>Defaulted          </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum       </td><td>enum   </td><td>int               </td><td>enum                          </td><td>enum       </td><td>int               </td><td>int               </td><td>int              </td><td>int               </td><td>int               </td><td>int               </td><td>int               </td><td>int               </td><td>enum       </td><td>enum    </td><td>int                </td><td>int               </td><td>int               </td><td>int               </td><td>int                </td></tr>
# <tr><td>mins   </td><td>           </td><td>       </td><td>0.0               </td><td>                              </td><td>           </td><td>0.0               </td><td>0.0               </td><td>0.0              </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>           </td><td>        </td><td>0.0                </td><td>0.0               </td><td>300.0             </td><td>150.0             </td><td>0.0                </td></tr>
# <tr><td>mean   </td><td>           </td><td>       </td><td>53875.82003505482 </td><td>                              </td><td>           </td><td>398750.95628383703</td><td>110.75986138235076</td><td>11.41085497195173</td><td>1.2805620317143915</td><td>8.247082845843469 </td><td>10.620207214701653</td><td>2756.757912905765 </td><td>0.757737186987023 </td><td>           </td><td>        </td><td>201167.6448189652  </td><td>5.320433202396893 </td><td>192663.99781130027</td><td>149487.48882072695</td><td>0.17522721105382333</td></tr>
# <tr><td>maxs   </td><td>           </td><td>       </td><td>99999.0           </td><td>                              </td><td>           </td><td>928120.0          </td><td>569.0             </td><td>9999.0           </td><td>2.0               </td><td>8800.0            </td><td>8800.0            </td><td>99999.0           </td><td>2.0               </td><td>           </td><td>        </td><td>11000000.0         </td><td>996262.0          </td><td>5472000.0         </td><td>5472000.0         </td><td>1.0                </td></tr>
# <tr><td>sigma  </td><td>           </td><td>       </td><td>31171.887960162265</td><td>                              </td><td>           </td><td>263245.11754311254</td><td>78.85231288246004 </td><td>76.16156831435656</td><td>0.4518319973213188</td><td>233.03559054729357</td><td>233.53310770107086</td><td>12775.155879795077</td><td>0.6463702363252029</td><td>           </td><td>        </td><td>287792.7934812004  </td><td>2026.2605531281793</td><td>283645.0333100023 </td><td>228998.74605927628</td><td>0.3801617511281878 </td></tr>
# <tr><td>zeros  </td><td>           </td><td>       </td><td>151               </td><td>                              </td><td>           </td><td>100802            </td><td>392               </td><td>3297             </td><td>518               </td><td>314923            </td><td>220341            </td><td>104829            </td><td>161568            </td><td>           </td><td>        </td><td>100                </td><td>449574            </td><td>0                 </td><td>0                 </td><td>370803             </td></tr>
# <tr><td>missing</td><td>16         </td><td>8      </td><td>0                 </td><td>762                           </td><td>763        </td><td>0                 </td><td>0                 </td><td>0                </td><td>70                </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                 </td><td>2297       </td><td>2044    </td><td>0                  </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                  </td></tr>
# <tr><td>0      </td><td>BETHESDA   </td><td>MD     </td><td>20814.0           </td><td>WACHOVIA SBA LENDING, INC.    </td><td>CA         </td><td>621111.0          </td><td>300.0             </td><td>9.0              </td><td>1.0               </td><td>0.0               </td><td>9.0               </td><td>1.0               </td><td>1.0               </td><td>0          </td><td>N       </td><td>740400.0           </td><td>0.0               </td><td>740400.0          </td><td>555300.0          </td><td>0.0                </td></tr>
# <tr><td>1      </td><td>FRANKFORT  </td><td>IL     </td><td>60423.0           </td><td>CENTRUE BANK                  </td><td>IL         </td><td>561730.0          </td><td>48.0              </td><td>6.0              </td><td>1.0               </td><td>5.0               </td><td>6.0               </td><td>0.0               </td><td>1.0               </td><td>N          </td><td>N       </td><td>30000.0            </td><td>0.0               </td><td>30000.0           </td><td>15000.0           </td><td>0.0                </td></tr>
# <tr><td>2      </td><td>MARBLEHEAD </td><td>MA     </td><td>1945.0            </td><td>WELLS FARGO BANK NATL ASSOC   </td><td>SD         </td><td>421690.0          </td><td>60.0              </td><td>1.0              </td><td>1.0               </td><td>0.0               </td><td>0.0               </td><td>1.0               </td><td>0.0               </td><td>T          </td><td>N       </td><td>25000.0            </td><td>0.0               </td><td>25000.0           </td><td>12500.0           </td><td>0.0                </td></tr>
# <tr><td>3      </td><td>LAS VEGAS  </td><td>NV     </td><td>89104.0           </td><td>NEW VENTURES CAP. DEVEL CO    </td><td>NV         </td><td>0.0               </td><td>240.0             </td><td>1.0              </td><td>2.0               </td><td>17.0              </td><td>1.0               </td><td>1.0               </td><td>0.0               </td><td>N          </td><td>N       </td><td>327000.0           </td><td>0.0               </td><td>327000.0          </td><td>327000.0          </td><td>0.0                </td></tr>
# <tr><td>4      </td><td>OAKLAND    </td><td>CA     </td><td>94608.0           </td><td>CITICAPITAL SMALL BUS. FINANCE</td><td>TX         </td><td>0.0               </td><td>29.0              </td><td>10.0             </td><td>1.0               </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>N          </td><td>N       </td><td>75000.0            </td><td>0.0               </td><td>75000.0           </td><td>67500.0           </td><td>0.0                </td></tr>
# <tr><td>5      </td><td>WHEATRIDGE </td><td>CO     </td><td>80033.0           </td><td>VECTRA BK COLORADO NATL ASSOC </td><td>NM         </td><td>531110.0          </td><td>120.0             </td><td>2.0              </td><td>1.0               </td><td>0.0               </td><td>2.0               </td><td>0.0               </td><td>1.0               </td><td>T          </td><td>N       </td><td>70520.0            </td><td>0.0               </td><td>50000.0           </td><td>25000.0           </td><td>0.0                </td></tr>
# <tr><td>6      </td><td>BOISE      </td><td>ID     </td><td>83705.0           </td><td>BANK OF AMERICA NATL ASSOC    </td><td>OR         </td><td>326191.0          </td><td>84.0              </td><td>80.0             </td><td>1.0               </td><td>0.0               </td><td>0.0               </td><td>1.0               </td><td>0.0               </td><td>N          </td><td>N       </td><td>700000.0           </td><td>0.0               </td>

# %% [markdown]
# Use `fillna` method to fill missing values for the following columns:
# - City
# - State
# - Bank
# - BankState
# - NewExist
# - RevLineCr
# - LowDoc
#
# https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-munging/fillnas.html

# %%
columns = ["City","State","Bank","BankState",
           "NewExist", "RevLineCr","LowDoc"]
num_col_ind = df_h.columns_by_type(coltype="numeric")
str_col_ind = df_h.columns_by_type(coltype="string")
enum_col_ind = df_h.columns_by_type(coltype="categorical")
all_columns = df_h.columns
num_col = []
str_col = []
enum_col = []

for col in columns:
    if all_columns.index(col) in num_col_ind:
        print("Fillna for numerical column:...", col)
        num_col.append(col)
        
        filled = df_h[col].fillna(method="forward",axis=1,maxlen=1)
        df_h[col] = filled
        '''Alternative way '''
        #df_h[df_h[col].isna(), col] = 0
    elif all_columns.index(col) in enum_col_ind:
        print("Fillna for categorical column:...", col)
        enum_col.append(col)
        df_h[col] = df_h[col].ascharacter()
        df_h[df_h[col].isna(), col] = "Missing"
        df_h[col] = df_h[col].asfactor()
    elif all_columns.index(col) in str_col_ind:
        print("Fillna for string column:...", col)
        str_col.append(col)
        df_h[df_h[col].isna(), col] = "Missing"
# Out:
# Fillna for categorical column:... City
# Fillna for categorical column:... State
# Fillna for categorical column:... Bank
# Fillna for categorical column:... BankState
# Fillna for numerical column:... NewExist
# Fillna for categorical column:... RevLineCr
# Fillna for categorical column:... LowDoc

# %% [markdown]
# ### Correct variables types - make non-numerical columns "factor" (categorical)

# %%
# Choose which columns to encode
encoded_columns = enum_col + str_col + ['Zip']
response = "Defaulted"

df_h[encoded_columns+[response]] = df_h[encoded_columns+[response]].asfactor()

# %% [markdown]
# ## Split to train/test/validation

# %%
train,test,valid = df_h.split_frame(ratios=[.7, .15], seed=123)

# %% [markdown]
# ### Perform target encoding on the following columns
#
# https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/target-encoding.html

# %%
encoded_columns
# Out:
# ['City', 'State', 'Bank', 'BankState', 'RevLineCr', 'LowDoc', 'Zip']

# %%
from h2o.estimators import H2OTargetEncoderEstimator

# Choose which columns to encode
encoded_columns = enum_col + str_col + ['Zip']
response = "Defaulted"

# Train a Target Encoder model
data_te = H2OTargetEncoderEstimator(#fold_column=fold_column,
                                    data_leakage_handling=None,
                                    blending=True,
                                    inflection_point=3,
                                    smoothing=10,
                                    noise=0.15,     # In general, the less data you have the more regularization you need
                                    seed=1234)

data_te.train(x=encoded_columns,
              y=response,
              training_frame=train)

# New target encoded dataset
train_te = data_te.transform(frame=train, as_training=True)
valid_te = data_te.transform(frame=test, as_training=False)
test_te = data_te.transform(frame=valid, as_training=False)
# Out:
# targetencoder Model Build progress: |████████████████████████████████████████████| (done) 100%

# %%
train_te.describe()
# Out:
# Rows:314835
# Cols:27
# <table>
# <thead>
# <tr><th>       </th><th>City_te              </th><th>State_te            </th><th>Zip_te              </th><th>Bank_te             </th><th>BankState_te        </th><th>RevLineCr_te        </th><th>LowDoc_te           </th><th>City      </th><th>State  </th><th>Zip  </th><th>Bank                          </th><th>BankState  </th><th>RevLineCr  </th><th>LowDoc  </th><th>NAICS             </th><th>Term              </th><th>NoEmp             </th><th>NewExist           </th><th>CreateJob         </th><th>RetainedJob       </th><th>FranchiseCode    </th><th>UrbanRural        </th><th>DisbursementGross  </th><th>BalanceGross     </th><th>GrAppv            </th><th>SBA_Appv         </th><th>Defaulted  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>real                 </td><td>real                </td><td>real                </td><td>real                </td><td>real                </td><td>real                </td><td>real                </td><td>enum      </td><td>enum   </td><td>enum </td><td>enum                          </td><td>enum       </td><td>enum       </td><td>enum    </td><td>int               </td><td>int               </td><td>int               </td><td>int                </td><td>int               </td><td>int               </td><td>int              </td><td>int               </td><td>int                </td><td>int              </td><td>int               </td><td>int              </td><td>enum       </td></tr>
# <tr><td>mins   </td><td>-0.1437745976786964  </td><td>-0.08558249324118866</td><td>-0.14695214828591374</td><td>-0.149949216841022  </td><td>-0.12052854682017504</td><td>-0.1262983923818528 </td><td>-0.06091226164867272</td><td>          </td><td>       </td><td>     </td><td>                              </td><td>           </td><td>           </td><td>        </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>0.0                </td><td>0.0               </td><td>0.0               </td><td>0.0              </td><td>0.0               </td><td>0.0                </td><td>0.0              </td><td>300.0             </td><td>150.0            </td><td>           </td></tr>
# <tr><td>mean   </td><td>0.17525508998539058  </td><td>0.17497524104376355 </td><td>0.17539311916590614 </td><td>0.17580158570976578 </td><td>0.17497660895395073 </td><td>0.1749816275112649  </td><td>0.174975388600201   </td><td>          </td><td>       </td><td>     </td><td>                              </td><td>           </td><td>           </td><td>        </td><td>398534.00202963466</td><td>110.91156319977134</td><td>11.509012657423726</td><td>1.280475872804092  </td><td>8.710470563946194 </td><td>11.076312989343615</td><td>2763.815452538633</td><td>0.7575174297647973</td><td>200922.52741912435 </td><td>7.090580780408786</td><td>192443.64115171434</td><td>149375.5042419045</td><td>           </td></tr>
# <tr><td>maxs   </td><td>0.785893517993496    </td><td>0.42402727515770544 </td><td>0.9101779058715646  </td><td>1.0212540485116688  </td><td>0.5354784207521788  </td><td>0.5791866996958035  </td><td>0.6230070888487687  </td><td>          </td><td>       </td><td>     </td><td>                              </td><td>           </td><td>           </td><td>        </td><td>928120.0          </td><td>569.0             </td><td>9999.0            </td><td>2.0                </td><td>8800.0            </td><td>8800.0            </td><td>99999.0          </td><td>2.0               </td><td>8607858.0          </td><td>996262.0         </td><td>5472000.0         </td><td>5472000.0        </td><td>           </td></tr>
# <tr><td>sigma  </td><td>0.12083445325069325  </td><td>0.09662470010381322 </td><td>0.13036610073129998 </td><td>0.15258021724958776 </td><td>0.1152022179460063  </td><td>0.10331538239634881 </td><td>0.09284922264533867 </td><td>          </td><td>       </td><td>     </td><td>                              </td><td>           </td><td>           </td><td>        </td><td>263440.3585644509 </td><td>78.9169582391072  </td><td>80.76113270408644 </td><td>0.45193271034493454</td><td>242.11437380967863</td><td>242.4640886451514 </td><td>12806.77553875163</td><td>0.6465630523045285</td><td>286626.0327788897  </td><td>2413.86881141197 </td><td>282903.16978601116</td><td>228655.0463261251</td><td>           </td></tr>
# <tr><td>zeros  </td><td>0                    </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0                   </td><td>          </td><td>       </td><td>     </td><td>                              </td><td>           </td><td>           </td><td>        </td><td>70747             </td><td>278               </td><td>2252              </td><td>383                </td><td>220539            </td><td>154552            </td><td>72961            </td><td>113234            </td><td>75                 </td><td>314831           </td><td>0                 </td><td>0                </td><td>           </td></tr>
# <tr><td>missing</td><td>0                    </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0                   </td><td>0         </td><td>0      </td><td>0    </td><td>0                             </td><td>0          </td><td>0          </td><td>0       </td><td>0                 </td><td>0                 </td><td>0                 </td><td>45                 </td><td>0                 </td><td>0                 </td><td>0                </td><td>0                 </td><td>0                  </td><td>0                </td><td>0                 </td><td>0                </td><td>0          </td></tr>
# <tr><td>0      </td><td>0.1898125820812527   </td><td>0.26162576785935976 </td><td>0.19967623159904307 </td><td>0.08126578707804624 </td><td>0.28957351440250284 </td><td>0.21800813514866518 </td><td>0.25627868889315736 </td><td>BETHESDA  </td><td>MD     </td><td>20814</td><td>WACHOVIA SBA LENDING, INC.    </td><td>CA         </td><td>0          </td><td>N       </td><td>621111.0          </td><td>300.0             </td><td>9.0               </td><td>1.0                </td><td>0.0               </td><td>9.0               </td><td>1.0              </td><td>1.0               </td><td>740400.0           </td><td>0.0              </td><td>740400.0          </td><td>555300.0         </td><td>0          </td></tr>
# <tr><td>1      </td><td>0.12823702212714713  </td><td>0.15794599135403178 </td><td>0.024643811850561387</td><td>0.07418434584979167 </td><td>0.15061038648900382 </td><td>0.0778870932927953  </td><td>0.11781470893366947 </td><td>FRANKFORT </td><td>IL     </td><td>60423</td><td>CENTRUE BANK                  </td><td>IL         </td><td>N          </td><td>N       </td><td>561730.0          </td><td>48.0              </td><td>6.0               </td><td>1.0                </td><td>5.0               </td><td>6.0               </td><td>0.0              </td><td>1.0               </td><td>30000.0            </td><td>0.0              </td><td>30000.0           </td><td>15000.0          </td><td>0          </td></tr>
# <tr><td>2      </td><td>0.10543414006032795  </td><td>0.16625725781027384 </td><td>0.09736257617382421 </td><td>0.18066908833133621 </td><td>0.21766751452973976 </td><td>0.4686637559606808  </td><td>0.22590896604998723 </td><td>MARBLEHEAD</td><td>MA     </td><td>1945 </td><td>WELLS FARGO BANK NATL ASSOC   </td><td>SD         </td><td>T          </td><td>N       </td><td>421690.0          </td><td>60.0              </td><td>1.0               </td><td>1.0                </td><td>0.0               </td><td>0.0               </td><td>1.0              </td><td>0.0               </td><td>25000.0            </td><td>0.0              </td><td>25000.0           </td><td>12500.0          </td><td>0          </td></tr>
# <tr><td>3      </td><td>0.36526189536022124  </td><td>0.3317355073335

# %% [markdown]
# ## Question 1 - solved for everyone to help with set up
#
# Use H2O-3 to train GLM with binomial classification (`family=binomial`)
#
# https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/glm.html

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
predictors = train_te.columns
for col in encoded_columns+str_col:
    predictors.remove(col)
predictors.remove("Defaulted")
print("Predictor columns:", predictors)    
response_col = "Defaulted"
glm_model = H2OGeneralizedLinearEstimator(family="binomial",
                                          nfolds=0, #No cross-validation (faster)
                                          alpha=0,
                                          lambda_=0.3,
                                          compute_p_values=False,
                                          seed=123)
glm_model.train(predictors, response_col, training_frame= train_te)
model_summary = glm_model.summary()
print(model_summary)
# Out:
# Predictor columns: ['City_te', 'State_te', 'Zip_te', 'Bank_te', 'BankState_te', 'RevLineCr_te', 'LowDoc_te', 'NAICS', 'Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural', 'DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv']
# glm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
#
# GLM Model: summary
#        family   link          regularization  number_of_predictors_total  \
# 0    binomial  logit  Ridge ( lambda = 0.3 )                          19
#
#   number_of_active_predictors  number_of_iterations  \
# 0                          19                     3
#
#                       training_frame
# 0  _837cff135a63cdae3a960b433036403c

# %% [markdown]
# ### Evaluate model on testing dataset

# %%
glm_model.model_performance(test_te)
# Out:
# ModelMetricsBinomialGLM: glm
# ** Reported on test data. **
#
# MSE: 0.13011073602031084
# RMSE: 0.360708658088922
# LogLoss: 0.41583869416986025
# Null degrees of freedom: 67412
# Residual degrees of freedom: 67393
# Null deviance: 62844.02125549804
# Residual deviance: 56065.86778014556
# AIC: 56105.86778014556
# AUC: 0.760560783056992
# AUCPR: 0.4264478538826738
# Gini: 0.5211215661139841
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.2126026875384351:
#                 0        1   Error                Rate
# 0      0  43675.0  11837.0  0.2132   (11837.0/55512.0)
# 1      1   5016.0   6885.0  0.4215    (5016.0/11901.0)
# 2  Total  48691.0  18722.0    0.25   (16853.0/67413.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.212603      0.449662  182.0
# 1                        max f2   0.158384      0.588857  258.0
# 2                  max f0point5   0.262274      0.446803  124.0
# 3                  max accuracy   0.317213      0.833148   76.0
# 4                 max precision   0.596815      1.000000    0.0
# 5                    max recall   0.042318      1.000000  393.0
# 6               max specificity   0.596815      1.000000    0.0
# 7              max absolute_mcc   0.234197      0.313426  156.0
# 8    max min_per_class_accuracy   0.191270      0.689522  211.0
# 9   max mean_per_class_accuracy   0.194493      0.690266  207.0
# 10                      max tns   0.596815  55512.000000    0.0
# 11                      max fns   0.596815  11900.000000    0.0
# 12                      max fps   0.016168  55512.000000  399.0
# 13                      max tps   0.042318  11901.000000  393.0
# 14                      max tnr   0.596815      1.000000    0.0
# 15                      max fnr   0.596815      0.999916    0.0
# 16                      max fpr   0.016168      1.000000  399.0
# 17                      max tpr   0.042318      1.000000  393.0
# Gains/Lift Table: Avg response rate: 17.65 %, avg score: 17.46 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010013         0.377481  4.103602
# 1       2                  0.020011         0.349181  3.521392
# 2       3                  0.030009         0.330251  3.344902
# 3       4                  0.040007         0.316425  3.033944
# 4       5                  0.050005         0.305620  2.807028
# 5       6                  0.100010         0.270399  2.384426
# 6       7                  0.150001         0.248578  1.971643
# 7       8                  0.200006         0.232034  1.665233
# 8       9                  0.300001         0.207156  1.361291
# 9      10                  0.399997         0.186639  1.052059
# 10     11                  0.500007         0.168391  0.883868
# 11     12                  0.600003         0.150490  0.698292
# 12     13                  0.699999         0.131386  0.532752
# 13     14                  0.799994         0.109270  0.378136
# 14     15                  0.899990         0.084111  0.270578
# 15     16                  1.000000         0.016071  0.131068
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          4.103602       0.724444  0.415096                  0.724444
# 1          3.812713       0.621662  0.362245                  0.673091
# 2          3.656853       0.590504  0.339146                  0.645576
# 3          3.501183       0.535608  0.322985                  0.618094
# 4          3.362393       0.495549  0.310859                  0.593592
# 5          2.873410       0.420943  0.286232                  0.507268
# 6          2.572880       0.348071  0.258933                  0.454213
# 7          2.345952       0.293978  0.239769                  0.414151
# 8          2.017748       0.240320  0.218935                  0.356210
# 9          1.776334       0.185729  0.196531                  0.313592
# 10         1.597825       0.156037  0.177407                  0.282078
# 11         1.447910       0.123275  0.159454                  0.255612
# 12         1.317179       0.094051  0.141118                  0.232533
# 13         1.199803       0.066756  0.120657                  0.211812
# 14         1.096559       0.047767  0.097021                  0.193585
# 15         1.000000       0.023139  0.067611                  0.176539
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.415096      0.041089                 0.041089  310.360250
# 1           0.388690      0.035207                 0.076296  252.139161
# 2           0.372184      0.033443                 0.109739  234.490182
# 3           0.359889      0.030334                 0.140072  203.394361
# 4           0.350085      0.028065                 0.168137  180.702816
# 5           0.318159      0.119234                 0.287371  138.442596
# 6           0.298421      0.098563                 0.385934   97.164313
# 7           0.283757      0.083270                 0.469204   66.523335
# 8           0.262151      0.136123                 0.605327   36.129073
# 9           0.245746      0.105201                 0.710529    5.205925
# 10          0.232077      0.088396                 0.798924  -11.613245
# 11          0.219974      0.069826                 0.868751  -30.170827
# 12          0.208709      0.053273                 0.922023  -46.724795
# 13          0.197703      0.037812                 0.959835  -62.186369
# 14          0.186517      0.027057                 0.986892  -72.942246
# 15          0.174625      0.013108                 1.000000  -86.893219
#
#     cumulative_gain  kolmogorov_smirnov
# 0        310.360250            0.037738
# 1        281.271285            0.068352
# 2        265.685292            0.096823
# 3        250.118334            0.121518
# 4        236.239348            0.143458
# 5        187.340972            0.227528
# 6        157.288031            0.286514
# 7        134.595174            0.326911
# 8        101.774763            0.370783
# 9         77.633449            0.377105
# 10        59.782522            0.363001
# 11        44.791038            0.326363
# 12        31.717902            0.269624
# 13        19.980303            0.194109
# 14         9.655916            0.105533
# 15         0.000000            0.000000

# %% [markdown]
# ### Example of extracting model performance metrics from the "model_performance" method output

# %%
print("Best accuracy threshold:",glm_model.model_performance(test_te).accuracy()[0][0],
      " Accuracy:",
      glm_model.model_performance(test_te).accuracy()[0][1])
print("Best F1 threshold:",glm_model.model_performance(test_te).F1()[0][0],
      " F1:",
      glm_model.model_performance(test_te).F1()[0][1])
print("Model AUC:", glm_model.model_performance(test_te).auc())
# Out:
# Best accuracy threshold: 0.31721333255884554  Accuracy: 0.8331479091569876
# Best F1 threshold: 0.2126026875384351  F1: 0.4496620187440813
# Model AUC: 0.760560783056992

# %% [markdown]
# ### Print Coefficients

# %%
# Print the Coefficients table
glm_model._model_json['output']['coefficients_table']
# Out:
# Coefficients: glm coefficients
#                 names  coefficients  standardized_coefficients
# 0           Intercept -1.885570e+00                  -1.643094
# 1             City_te  9.622130e-01                   0.116268
# 2            State_te -4.327879e-01                  -0.041818
# 3              Zip_te  1.209352e+00                   0.157659
# 4             Bank_te  1.156602e+00                   0.176475
# 5        BankState_te  2.894366e-01                   0.033344
# 6        RevLineCr_te -1.893636e-01                  -0.019564
# 7           LowDoc_te -5.470972e-01                  -0.050798
# 8               NAICS  2.163698e-07                   0.057001
# 9                Term -3.006346e-03                  -0.237252
# 10              NoEmp -1.434826e-04                  -0.011588
# 11           NewExist  1.477712e-02                   0.006678
# 12          CreateJob  4.791825e-05                   0.011602
# 13        RetainedJob  4.849534e-05                   0.011758
# 14      FranchiseCode -4.822575e-07                  -0.006176
# 15         UrbanRural  1.599907e-01                   0.103444
# 16  DisbursementGross -1.096023e-07                  -0.031415
# 17       BalanceGross -3.371845e-07                  -0.000814
# 18             GrAppv -1.323202e-07                  -0.037434
# 19           SBA_Appv -2.078421e-07                  -0.047524

# %% [markdown]
# ## Question 2
#
# Alpha setting explanation: https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/algo-params/alpha.html
# - `alpha=1` - Lasso regression
# - `alpha=0` - Ridge regression
#
# In order for GLM to use regularization, `lambda_` parameter must be set to be greater than `0`.
#
# Find best parameters using H2O GridSearch for the following search space. Modify code as needed to make it work:
# ```
# # GLM hyperparameters
# glm_params  = {'alpha': [0, 0.1, 0.2, 0.3,0.5,0.7,0.8,0.9,1],
#                'lambda': [0.01, 0.05, 0.1, 0.2, 0.3, 0.4]}
#
# # Train and validate a cartesian grid of GLMs
# glm_grid  = H2OGridSearch(model=H2OGeneralizedLinearEstimator,
#                           grid_id='glm_grid1',
#                           hyper_params=glm_params)
#
# glm_grid.train(x=x, y=y,
#                family='binomial',
#                training_frame=train,
#                validation_frame=valid,
#                seed=123)
# ```
# Answer following questions:
# - What is the best set of parameters for the GLM function?
# - What is the best model performance (AUC) on validation dataset?
# - What is the best model performance (AUC) on test dataset?

# %%
from h2o.grid.grid_search import H2OGridSearch

# %%
hyper_params = {'alpha': [0, 0.1, 0.2, 0.3,0.5,0.7,0.8,0.9,1],'lambda': [0.01, 0.05, 0.1, 0.2, 0.3, 0.4]}

# %%
model_glm_2 = H2OGeneralizedLinearEstimator()

# %%
grid = H2OGridSearch(model = model_glm_2, hyper_params = hyper_params,
                     search_criteria = {'strategy': "Cartesian"})

# %%
grid1 = grid.train(family = 'binomial',x = predictors, y = response_col, training_frame = train_te, validation_frame = valid_te,seed = 123)
# Out:
# glm Grid Build progress: |███████████████████████████████████████████████████████| (done) 100%
# /Applications/anaconda3/lib/python3.9/site-packages/h2o/grid/grid_search.py:427: UserWarning: Adding alpha array to hyperparameter runs slower with gridsearch. This is due to the fact that the algo has to run initialization for every alpha value. Setting the alpha array as a model parameter will skip the initialization and run faster overall.
#   warnings.warn(w_message)

# %%
perf1 = grid1.get_grid(sort_by='auc', decreasing=True)
perf1
# Out:
#       alpha  lambda  \
# 0       1.0    0.10
# 1       0.5    0.20
# 2       1.0    0.01
# 3       0.9    0.10
# 4       0.9    0.01
# 5       0.8    0.01
# 6       0.7    0.01
# 7       0.5    0.01
# 8       0.3    0.01
# 9       0.2    0.01
# 10      0.1    0.01
# 11      0.0    0.01
# 12      0.8    0.10
# 13      0.3    0.30
# 14      0.2    0.05
# 15      0.1    0.05
# 16      0.3    0.05
# 17      0.0    0.05
# 18      1.0    0.05
# 19      0.7    0.10
# 20      0.9    0.05
# 21      0.5    0.05
# 22      0.8    0.05
# 23      0.7    0.05
# 24      0.0    0.10
# 25      0.1    0.10
# 26      0.2    0.40
# 27      0.5    0.10
# 28      0.2    0.10
# 29      0.3    0.10
# 30      0.3    0.20
# 31      0.0    0.20
# 32      0.2    0.30
# 33      0.2    0.20
# 34      0.1    0.20
# 35      0.0    0.30
# 36      0.1    0.30
# 37      0.0    0.40
# 38      0.1    0.40
# 39      0.7    0.20
# 40      0.8    0.20
# 41      0.9    0.20
# 42      1.0    0.20
# 43      0.5    0.30
# 44      0.7    0.30
# 45      0.8    0.30
# 46      0.9    0.30
# 47      1.0    0.30
# 48      0.3    0.40
# 49      0.5    0.40
# 50      0.7    0.40
# 51      0.8    0.40
# 52      0.9    0.40
# 53      1.0    0.40
#
#                                                                 model_ids  \
# 0   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 1   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 2   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 3   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 4   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 5   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 6   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 7   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 8   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 9   Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 10  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 11  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 12  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 13  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 14  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 15  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 16  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 17  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 18  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 19  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 20  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 21  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 22  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 23  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 24  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 25  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 26  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 27  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 28  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 29  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 30  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 31  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 32  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 33  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 34  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 35  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 36  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 37  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 38  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 39  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 40  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 41  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 42  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 43  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 44  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 45  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 46  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 47  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 48  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 49  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 50  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 51  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 52  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
# 53  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261...
#
#          auc
# 0   0.829422
# 1   0.827458
# 2   0.818298
# 3   0.818189
# 4   0.817949
# 5   0.817207
# 6   0.816840
# 7   0.815714
# 8   0.814290
# 9   0.813810
# 10  0.813331
# 11  0.812922
# 12  0.807118
# 13  0.806194
# 14  0.799328
# 15  0.799103
# 16  0.798655
# 17  0.798050
# 18  0.797159
# 19  0.795928
# 20  0.794149
# 21  0.793141
# 22  0.791922
# 23  0.791876
# 24  0.787140
# 25  0.786997
# 26  0.784952
# 27  0.781737
# 28  0.780632
# 29  0.777431
# 30  0.775434
# 31  0.772493
# 32  0.768258
# 33  0.766396
# 34  0.762910
# 35  0.762662
# 36  0.756910
# 37  0.755736
# 38  0.755057
# 39  0.500000
# 40  0.500000
# 41  0.500000
# 42  0.500000
# 43  0.500000
# 44  0.500000
# 45  0.500000
# 46  0.500000
# 47  0.500000
# 48  0.500000
# 49  0.500000
# 50  0.500000
# 51  0.500000
# 52  0.500000
# 53  0.500000

# %%
best_model = grid1.models[0]

# %%
best_model
# Out:
# Model Details
# =============
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  Grid_GLM__837cff135a63cdae3a960b433036403c_model_python_1646745261788_10_model_9
#
#
# GLM Model: summary
#        family   link          regularization  number_of_predictors_total  \
# 0    binomial  logit  Lasso (lambda = 0.01 )                          19
#
#   number_of_active_predictors  number_of_iterations  \
# 0                          10                     7
#
#                       training_frame
# 0  _837cff135a63cdae3a960b433036403c
# ModelMetricsBinomialGLM: glm
# ** Reported on train data. **
#
# MSE: 0.09997761252256532
# RMSE: 0.31619236632557296
# LogLoss: 0.3320940391986627
# Null degrees of freedom: 314834
# Residual degrees of freedom: 314824
# Null deviance: 292015.94703569054
# Residual deviance: 209109.65366222194
# AIC: 209131.65366222194
# AUC: 0.863354727037088
# AUCPR: 0.6419596946072199
# Gini: 0.7267094540741761
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.2967367004579483:
#                  0        1   Error                 Rate
# 0      0  235653.0  24079.0  0.0927   (24079.0/259732.0)
# 1      1   20396.0  34707.0  0.3701    (20396.0/55103.0)
# 2  Total  256049.0  58786.0  0.1413   (44475.0/314835.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold          value    idx
# 0                        max f1   0.296737       0.609488  194.0
# 1                        max f2   0.208518       0.686367  244.0
# 2                  max f0point5   0.396975       0.641450  147.0
# 3                  max accuracy   0.396975       0.872702  147.0
# 4                 max precision   0.947030       0.979167    1.0
# 5                    max recall   0.001415       1.000000  399.0
# 6               max specificity   0.961225       0.999996    0.0
# 7              max absolute_mcc   0.296737       0.523778  194.0
# 8    max min_per_class_accuracy   0.210240       0.791751  243.0
# 9   max mean_per_class_accuracy   0.227324       0.792144  233.0
# 10                      max tns   0.961225  259731.000000    0.0
# 11                      max fns   0.961225   55083.000000    0.0
# 12                      max fps   0.001415  259732.000000  399.0
# 13                      max tps   0.001415   55103.000000  399.0
# 14                      max tnr   0.961225       0.999996    0.0
# 15                      max fnr   0.961225       0.999637    0.0
# 16                      max fpr   0.001415       1.000000  399.0
# 17                      max tpr   0.001415       1.000000  399.0
# Gains/Lift Table: Avg response rate: 17.50 %, avg score: 17.50 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010002         0.747225  5.203724
# 1       2                  0.020001         0.666869  4.942204
# 2       3                  0.030003         0.610559  4.739235
# 3       4                  0.040002         0.567464  4.528388
# 4       5                  0.050001         0.531437  4.261585
# 5       6                  0.100002         0.408455  3.670159
# 6       7                  0.150002         0.334650  2.669504
# 7       8                  0.200000         0.284098  1.961874
# 8       9                  0.300002         0.215178  1.290290
# 9      10                  0.400000         0.168357  0.727195
# 10     11                  0.500002         0.132430  0.436811
# 11     12                  0.600000         0.100331  0.299807
# 12     13                  0.699998         0.067378  0.229755
# 13     14                  0.800000         0.023703  0.261325
# 14     15                  0.899998         0.005898  0.199811
# 15     16                  1.000000         0.000047  0.036658
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          5.203724       0.910765  0.819585                  0.910765
# 1          5.072985       0.864994  0.704290                  0.887883
# 2          4.961723       0.829470  0.637925                  0.868410
# 3          4.853406       0.792567  0.588407                  0.849452
# 4          4.735057       0.745870  0.548940                  0.828738
# 5          4.202608       0.642358  0.463810                  0.735548
# 6          3.691573       0.467221  0.368758                  0.646106
# 7          3.259169       0.343371  0.308108                  0.570426
# 8          2.602869       0.225829  0.247122                  0.455559
# 9          2.133958       0.127275  0.190504                  0.373489
# 10         1.794525       0.076452  0.149825                  0.314081
# 11         1.545409       0.052473  0.116280                  0.270480
# 12         1.357461       0.040212  0.084300                  0.237585
# 13         1.220442       0.045738  0.046726                  0.213604
# 14         1.107040       0.034971  0.011679                  0.193756
# 15         1.000000       0.006416  0.003631                  0.175022
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.819585      0.052048                 0.052048  420.372394
# 1           0.761947      0.049417                 0.101465  394.220414
# 2           0.720602      0.047402                 0.148867  373.923533
# 3           0.687558      0.045279                 0.194146  352.838756
# 4           0.659838      0.042611                 0.236757  326.158477
# 5           0.561824      0.183511                 0.420267  267.015931
# 6           0.497469      0.133477                 0.553745  166.950373
# 7           0.450131      0.098089                 0.651834   96.187414
# 8           0.382461      0.129031                 0.780865   29.029038
# 9           0.334472      0.072718                 0.853583  -27.280481
# 10          0.297542      0.043682                 0.897265  -56.318862
# 11          0.267332      0.029980                 0.927245  -70.019305
# 12          0.241185      0.022975                 0.950220  -77.024480
# 13          0.216878      0.026133                 0.976353  -73.867537
# 14          0.194078      0.019981                 0.996334  -80.018919
# 15          0.175033      0.003666                 1.000000  -96.334196
#
#     cumulative_gain  kolmogorov_smirnov
# 0        420.372394            0.050966
# 1        407.298481            0.098746
# 2        396.172320            0.144081
# 3        385.340650            0.186846
# 4        373.505719            0.226377
# 5        320.260825            0.388211
# 6        269.157341            0.489398
# 7        225.916919            0.547692
# 8        160.286931            0.582880
# 9        113.395822            0.549812
# 10        79.452454            0.481544
# 11        54.540890            0.396672
# 12        35.746093            0.303308
# 13        22.044172            0.213767
# 14        10.703988            0.116774
# 15         0.000000            0.000000
# ModelMetricsBinomialGLM: glm
# ** Reported on validation data. **
#
# MSE: 0.11201603972952776
# RMSE: 0.3346879736852338
# LogLoss: 0.3663298598581461
# Null degrees of freedom: 67333
# Residual degrees of freedom: 67323
# Null deviance: 62422.90987972178
# Residual deviance: 49332.90956737682
# AIC: 49354.90956737682
# AUC: 0.8182980217009985
# AUCPR: 0.5236634753222081
# Gini: 0.636596043401997
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.2732400581155379:
#                 0        1   Error                Rate
# 0      0  48195.0   7364.0  0.1325    (7364.0/55559.0)
# 1      1   4747.0   7028.0  0.4031    (4747.0/11775.0)
# 2  Total  52942.0  14392.0  0.1799   (12111.0/67334.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.273240      0.537165  200.0
# 1                        max f2   0.171259      0.636459  267.0
# 2                  max f0point5   0.379631      0.539945  144.0
# 3                  max accuracy   0.440833      0.849883  116.0
# 4                 max precision   0.864331      0.820225    8.0
# 5                    max recall   0.001598      1.000000  399.0
# 6               max specificity   0.946003      0.999964    0.0
# 7              max absolute_mcc   0.279441      0.431492  196.0
# 8    max min_per_class_accuracy   0.200768      0.746582  246.0
# 9   max mean_per_class_accuracy   0.218167      0.748801  234.0
# 10                      max tns   0.946003  55557.000000    0.0
# 11                      max fns   0.946003  11773.000000    0.0
# 12                      max fps   0.001598  55559.000000  399.0
# 13                      max tps   0.001598  11775.000000  399.0
# 14                      max tnr   0.946003      0.999964    0.0
# 15                      max fnr   0.946003      0.999830    0.0
# 16                      max fpr   0.001598      1.000000  399.0
# 17                      max tpr   0.001598      1.000000  399.0
# Gains/Lift Table: Avg response rate: 17.49 %, avg score: 17.40 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010010         0.709829  4.369390
# 1       2                  0.020005         0.632181  4.256927
# 2       3                  0.030000         0.576552  4.078493
# 3       4                  0.040010         0.537312  3.868819
# 4       5                  0.050004         0.502126  3.611165
# 5       6                  0.100009         0.393382  2.992515
# 6       7                  0.149999         0.328413  2.476948
# 7       8                  0.200003         0.283055  1.949720
# 8       9                  0.299997         0.219178  1.364837
# 9      10                  0.400006         0.173115  0.878053
# 10     11                  0.500000         0.136783  0.621693
# 11     12                  0.599994         0.104589  0.424654
# 12     13                  0.700003         0.070760  0.324387
# 13     14                  0.799997         0.025966  0.346517
# 14     15                  0.899991         0.006203  0.247148
# 15     16                  1.000000         0.000245  0.064538
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          4.369390       0.764095  0.783363                  0.764095
# 1          4.313200       0.744428  0.668042                  0.754269
# 2          4.235003       0.713224  0.602849                  0.740594
# 3          4.143389       0.676558  0.556041                  0.724573
# 4          4.037008       0.631501  0.519330                  0.705970
# 5          3.514761       0.523315  0.442348                  0.614642
# 6          3.168892       0.433155  0.358707                  0.554158
# 7          2.864076       0.340956  0.304959                  0.500854
# 8          2.364355       0.238675  0.248940                  0.413465
# 9          1.992752       0.153549  0.195343                  0.348481
# 10         1.718556       0.108718  0.154451                  0.300532
# 11         1.502917       0.074261  0.120569                  0.262822
# 12         1.334541       0.056727  0.088141                  0.233377
# 13         1.211045       0.060597  0.049875                  0.211781
# 14         1.103951       0.043220  0.012762                  0.193053
# 15         1.000000       0.011286  0.003763                  0.174875
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.783363      0.043737                 0.043737  336.939021
# 1           0.725745      0.042548                 0.086285  325.692659
# 2           0.684800      0.040764                 0.127049  307.849254
# 3           0.652586      0.038726                 0.165775  286.881929
# 4           0.625951      0.036093                 0.201868  261.116527
# 5           0.534149      0.149639                 0.351507  199.251466
# 6           0.475680      0.123822                 0.475329  147.694812
# 7           0.432997      0.097495                 0.572824   94.972011
# 8           0.371647      0.136476                 0.709299   36.483692
# 9           0.327568      0.087813                 0.797113  -12.194661
# 10          0.292947      0.062166                 0.859278  -37.830702
# 11          0.264218      0.042463                 0.901741  -57.534632
# 12          0.239062      0.032442                 0.934183  -67.561277
# 13          0.215415      0.034650                 0.968832  -65.348260
# 14          0.192899      0.024713                 0.993546  -75.285156
# 15          0.173984      0.006454                 1.000000  -93.546223
#
#     cumulative_gain  kolmogorov_smirnov
# 0        336.939021            0.040875
# 1        331.320014            0.080327
# 2        323.500301            0.117617
# 3        314.338912            0.152420
# 4        303.700757            0.184049
# 5        251.476112            0.304800
# 6        216.889196            0.394280
# 7        186.407636            0.451835
# 8        136.435462            0.496049
# 9         99.275172            0.481268
# 10        71.855626            0.435422
# 11        50.291651            0.365698
# 12        33.454089            0.283811
# 13        21.104484            0.204618
# 14        10.395054            0.113382
# 15         0.000000            0.000000
# Scoring History:
#                timestamp    duration  iterations  negative_log_likelihood  \
# 0    2022-03-08 07:16:08   0.000 sec           0            146007.973518
# 1    2022-03-08 07:16:08   0.230 sec           1            115030.243061
# 2    2022-03-08 07:16:08   0.355 sec           2            109312.479054
# 3    2022-03-08 07:16:08   0.480 sec           3            107539.243321
# 4    2022-03-08 07:16:08   0.604 sec           4            107215.392851
# 5    2022-03-08 07:16:08   0.729 sec           5            107202.118403
# 6    2022-03-08 07:16:09   1.097 sec           6            104679.608015
# 7    2022-03-08 07:16:09   1.228 sec           7            104554.826831
#
#    objective training_rmse training_logloss training_r2 training_auc  \
# 0   0.463760
# 1   0.388393
# 2   0.373639
# 3   0.371326
# 4   0.371227
# 5   0.371227
# 6   0.367711
# 7   0.367693      0.316192         0.332094    0.307582     0.863355
#
#   training_pr_auc training_lift training_classification_error validation_rmse  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7         0.64196      5.203724                      0.141264        0.334688
#
#   validation_logloss validation_r2 validation_auc validation_pr_auc  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7            0.36633      0.223693       0.818298          0.523663
#
#   validation_lift validation_classification_error
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7         4.36939                        0.179865
# Variable Importances:
#              variable  relative_importance  scaled_importance  percentage
# 0                Term             1.359552           1.000000    0.381907
# 1              Zip_te             0.540435           0.397509    0.151811
# 2             Bank_te             0.514344           0.378318    0.144482
# 3            State_te             0.354038           0.260408    0.099452
# 4             City_te             0.222569           0.163707    0.062521
# 5           LowDoc_te             0.216893           0.159533    0.060927
# 6          UrbanRural             0.191104           0.140564    0.053682
# 7        RevLineCr_te             0.115229           0.084755    0.032368
# 8              GrAppv             0.035685           0.026248    0.010024
# 9               NAICS             0.010057           0.007397    0.002825
# 10       BankState_te             0.000000           0.000000    0.000000
# 11              NoEmp             0.000000           0.000000    0.000000
# 12           NewExist             0.000000           0.000000    0.000000
# 13          CreateJob             0.000000           0.000000    0.000000
# 14        RetainedJob             0.000000           0.000000    0.000000
# 15      FranchiseCode             0.000000           0.000000    0.000000
# 16  DisbursementGross             0.000000           0.000000    0.000000
# 17       BalanceGross             0.000000           0.000000    0.000000
# 18           SBA_Appv             0.000000           0.000000    0.000000

# %%
best_model_perf = best_model.model_performance(test_te)

# %%
best_model_perf
# Out:
# ModelMetricsBinomialGLM: glm
# ** Reported on test data. **
#
# MSE: 0.11303103758395056
# RMSE: 0.3362008887316489
# LogLoss: 0.369552446484376
# Null degrees of freedom: 67412
# Residual degrees of freedom: 67402
# Null deviance: 62844.02125549804
# Residual deviance: 49825.27814970248
# AIC: 49847.27814970248
# AUC: 0.8158922322350534
# AUCPR: 0.5260393179033157
# Gini: 0.6317844644701067
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.27968179469069604:
#                 0        1   Error                Rate
# 0      0  48618.0   6894.0  0.1242    (6894.0/55512.0)
# 1      1   5095.0   6806.0  0.4281    (5095.0/11901.0)
# 2  Total  53713.0  13700.0  0.1778   (11989.0/67413.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.279682      0.531698  194.0
# 1                        max f2   0.169998      0.635212  266.0
# 2                  max f0point5   0.351475      0.545899  156.0
# 3                  max accuracy   0.398200      0.848620  135.0
# 4                 max precision   0.961285      1.000000    0.0
# 5                    max recall   0.001667      1.000000  399.0
# 6               max specificity   0.961285      1.000000    0.0
# 7              max absolute_mcc   0.279682      0.424197  194.0
# 8    max min_per_class_accuracy   0.196725      0.745028  248.0
# 9   max mean_per_class_accuracy   0.206106      0.747721  241.0
# 10                      max tns   0.961285  55512.000000    0.0
# 11                      max fns   0.961285  11900.000000    0.0
# 12                      max fps   0.001667  55512.000000  399.0
# 13                      max tps   0.001667  11901.000000  399.0
# 14                      max tnr   0.961285      1.000000    0.0
# 15                      max fnr   0.961285      0.999916    0.0
# 16                      max fpr   0.001667      1.000000  399.0
# 17                      max tpr   0.001667      1.000000  399.0
# Gains/Lift Table: Avg response rate: 17.65 %, avg score: 17.26 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010013         0.707303  4.481235
# 1       2                  0.020011         0.627052  4.210542
# 2       3                  0.030009         0.573855  3.916393
# 3       4                  0.040007         0.535261  3.857563
# 4       5                  0.050005         0.502386  3.512987
# 5       6                  0.100010         0.391766  3.064970
# 6       7                  0.150001         0.326652  2.383453
# 7       8                  0.200006         0.281610  1.866876
# 8       9                  0.300001         0.216663  1.374736
# 9      10                  0.399997         0.171149  0.915930
# 10     11                  0.500007         0.135234  0.609969
# 11     12                  0.600003         0.103945  0.412589
# 12     13                  0.699999         0.070014  0.363011
# 13     14                  0.799994         0.024680  0.340323
# 14     15                  0.899990         0.006157  0.266376
# 15     16                  1.000000         0.000071  0.061333
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          4.481235       0.791111  0.784033                  0.791111
# 1          4.345989       0.743323  0.664950                  0.767235
# 2          4.202861       0.691395  0.600395                  0.741967
# 3          4.116568       0.681009  0.553434                  0.726733
# 4          3.995888       0.620178  0.517938                  0.705429
# 5          3.530429       0.541086  0.440451                  0.623257
# 6          3.148179       0.420772  0.356849                  0.555775
# 7          2.827830       0.329576  0.302726                  0.499221
# 8          2.343489       0.242694  0.246835                  0.413716
# 9          1.986612       0.161697  0.192701                  0.350714
# 10         1.711259       0.107683  0.152797                  0.302103
# 11         1.494825       0.072838  0.119527                  0.263894
# 12         1.333144       0.064085  0.087342                  0.235351
# 13         1.209046       0.060080  0.048386                  0.213443
# 14         1.104308       0.047026  0.012295                  0.194953
# 15         1.000000       0.010828  0.003749                  0.176539
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.784033      0.044870                 0.044870  348.123463
# 1           0.724536      0.042097                 0.086967  321.054224
# 2           0.683176      0.039156                 0.126124  291.639258
# 3           0.650753      0.038568                 0.164692  285.756265
# 4           0.624198      0.035123                 0.199815  251.298734
# 5           0.532324      0.153264                 0.353080  206.497037
# 6           0.473844      0.119150                 0.472229  138.345265
# 7           0.431061      0.093353                 0.565583   86.687614
# 8           0.369656      0.137467                 0.703050   37.473558
# 9           0.325419      0.091589                 0.794639   -8.406982
# 10          0.290891      0.061003                 0.855642  -39.003057
# 11          0.262332      0.041257                 0.896899  -58.741127
# 12          0.237334      0.036299                 0.933199  -63.698914
# 13          0.213717      0.034031                 0.967230  -65.967732
# 14          0.191337      0.026636                 0.993866  -73.362397
# 15          0.172576      0.006134                 1.000000  -93.866699
#
#     cumulative_gain  kolmogorov_smirnov
# 0        348.123463            0.042330
# 1        334.598877            0.081311
# 2        320.286082            0.116720
# 3        311.656829            0.151416
# 4        299.588791            0.181927
# 5        253.042914            0.307324
# 6        214.817926            0.391310
# 7        182.782973            0.443951
# 8        134.348896            0.489457
# 9         98.661250            0.479248
# 10        71.125938            0.431878
# 11        49.482498            0.360547
# 12        33.314410            0.283195
# 13        20.904602            0.203089
# 14        10.430837            0.114002
# 15         0.000000            0.000000

# %% [markdown]
# ## Question 3
#
# Use parameters from the GridSearch in question #2. Train new model as following:
# - Train model on a combined dataset: train+validation
# - Don't use cross-validation - `nfolds=0`
# - Evaluate trained model on test dataset
# - Compare AUC (test dataset) metrics from the question #2 and #3

# %%
data1 = train_te.rbind(valid_te)

# %%
predictors = data1.columns
for col in encoded_columns+str_col:
    predictors.remove(col)
predictors.remove("Defaulted")
print("Predictor columns:", predictors)    
response_col = "Defaulted"
# Out:
# Predictor columns: ['City_te', 'State_te', 'Zip_te', 'Bank_te', 'BankState_te', 'RevLineCr_te', 'LowDoc_te', 'NAICS', 'Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural', 'DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv']

# %%
glm_model = H2OGeneralizedLinearEstimator(family="binomial",
                                          alpha=1,
                                          link='logit',
                                          lambda_=0.01,
                                          compute_p_values=False,
                                          seed=123)
glm_model.train(predictors, response_col, training_frame= data1)
model_summary = glm_model.summary()
print(model_summary)
# Out:
# glm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
#
# GLM Model: summary
#        family   link          regularization  number_of_predictors_total  \
# 0    binomial  logit  Lasso (lambda = 0.01 )                          19
#
#   number_of_active_predictors  number_of_iterations  training_frame
# 0                          10                     7  py_25_sid_9550

# %%
best_model.auc(xval=False)
# Out:
# 0.863354727037088

# %%
glm_model.auc(xval=False)
# Out:
# 0.8563404330830428

# %% [markdown]
# #On Comparing cross-validation AUC metric from this question to the AUC metric calculated on validation dataset, we can conclude that grid searched model is performing better than this model.

# %% [markdown]
# ## Question 4
#
# Do you see improvement in AUC metric on testing dataset between best model of the grid search and model trained with the same hyper parameters but on train+validation?
#
# How do you explain the results?

# %% [markdown]
# #Slight superior outcomes in grid search model when contrasted with the model in question3 interms of AUC metric, the reason might be on the grounds that we have involved just train data in grid search model and approved on valid_te data. However, in Question3 we utilized the train+valid data. valid is a little piece which is recently added is slighly affecting the outcomes interms of getting the connection among predictors and response.
# Yet, on a generally speaking, The AUC metric isn't changing excessively high between both the model outcomes.
